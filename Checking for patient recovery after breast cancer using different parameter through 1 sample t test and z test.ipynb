# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv("breast_cancer_survival.csv")

# %%
dataset
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
list(dataset.columns)
# Out:
# ['Age',
#  'Gender',
#  'Protein1',
#  'Protein2',
#  'Protein3',
#  'Protein4',
#  'Tumour_Stage',
#  'Histology',
#  'ER status',
#  'PR status',
#  'HER2 status',
#  'Surgery_type',
#  'Date_of_Surgery',
#  'Date_of_Last_Visit',
#  'Patient_Status']

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 334 non-null    int64
#  1   Gender              334 non-null    object
#  2   Protein1            334 non-null    float64
#  3   Protein2            334 non-null    float64
#  4   Protein3            334 non-null    float64
#  5   Protein4            334 non-null    float64
#  6   Tumour_Stage        334 non-null    object
#  7   Histology           334 non-null    object
#  8   ER status           334 non-null    object
#  9   PR status           334 non-null    object
#  10  HER2 status         334 non-null    object
#  11  Surgery_type        334 non-null    object
#  12  Date_of_Surgery     334 non-null    object
#  13  Date_of_Last_Visit  317 non-null    object
#  14  Patient_Status      321 non-null    object
# ...

# %%
dataset.describe().T
# Out:
#           count       mean        std       min        25%        50%  \
# Age       334.0  58.886228  12.961212  29.00000  49.000000  58.000000
# Protein1  334.0  -0.029991   0.563588  -2.34090  -0.358888   0.006129
# Protein2  334.0   0.946896   0.911637  -0.97873   0.362173   0.992805
# Protein3  334.0  -0.090204   0.585175  -1.62740  -0.513748  -0.173180
# Protein4  334.0   0.009819   0.629055  -2.02550  -0.377090   0.041768
#
#                 75%      max
# Age       68.000000  90.0000
# Protein1   0.343598   1.5936
# Protein2   1.627900   3.4022
# Protein3   0.278353   2.1934
# Protein4   0.425630   1.6299

# %%
dataset.iloc[:,2:3].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of      Protein1
# 0    0.952560
# 1    0.000000
# 2   -0.523030
# 3   -0.876180
# 4    0.226110
# ..        ...
# 329  0.024598
# 330  0.100120
# 331  0.753820
# 332  0.972510
# 333  0.286380
#
# [334 rows x 1 columns]>

# %%
dataset['Protein1'].median()
# Out:
# 0.00612935

# %%
dataset['Protein2'].median()
# Out:
# 0.9928049999999999

# %%
dataset['Protein3'].median()
# Out:
# -0.17318

# %%
f=dataset.drop_duplicates(keep='first')

# %%
f['Protein1'].mean()
# Out:
# -0.02999121215568867

# %%
f['Protein2'].mean()
# Out:
# 0.946896182934132

# %%
f['Protein3'].mean()
# Out:
# -0.09020397544910179

# %%
f
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340           II
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320           II
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815           II
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190            I
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210           II
# ..   ...     ...       ...       ...       ...       ...          ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320           II
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870            I
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860           II
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820           II
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050           II
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
f.corr()
# Out:
#                Age  Protein1  Protein2  Protein3  Protein4
# Age       1.000000 -0.050638 -0.021542 -0.039686  0.094214
# Protein1 -0.050638  1.000000  0.238141 -0.129482  0.280343
# Protein2 -0.021542  0.238141  1.000000 -0.415825  0.088239
# Protein3 -0.039686 -0.129482 -0.415825  1.000000  0.065316
# Protein4  0.094214  0.280343  0.088239  0.065316  1.000000

# %%
#appling label encoding

from sklearn.preprocessing import LabelEncoder
r=LabelEncoder()
f['Tumour_Stage']=r.fit_transform(f['Tumour_Stage'])

# %%
f
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340             1
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320             1
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815             1
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190             0
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210             1
# ..   ...     ...       ...       ...       ...       ...           ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320             1
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870             0
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860             1
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820             1
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050             1
#
#                           Histology ER status PR status HER2 status  \
# ...

# %%
f.corr()
# Out:
#                    Age  Protein1  Protein2  Protein3  Protein4  Tumour_Stage
# Age           1.000000 -0.050638 -0.021542 -0.039686  0.094214     -0.167654
# Protein1     -0.050638  1.000000  0.238141 -0.129482  0.280343     -0.050201
# Protein2     -0.021542  0.238141  1.000000 -0.415825  0.088239     -0.051786
# Protein3     -0.039686 -0.129482 -0.415825  1.000000  0.065316      0.038271
# Protein4      0.094214  0.280343  0.088239  0.065316  1.000000     -0.037264
# Tumour_Stage -0.167654 -0.050201 -0.051786  0.038271 -0.037264      1.000000

# %%
plt.hist(f['Protein3'])
# Out:
# (array([ 3., 14., 75., 97., 64., 47., 17., 12.,  4.,  1.]),
#  array([-1.6274 , -1.24532, -0.86324, -0.48116, -0.09908,  0.283  ,
#          0.66508,  1.04716,  1.42924,  1.81132,  2.1934 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.heatmap(f.corr(),annot=True,cmap="BuPu")
# Out:
# <AxesSubplot:>

# %%
g=f.head(10)

# %%
plt.plot(g['Protein3']*100,g['Tumour_Stage'],)
plt.show()

# %% [raw]
# #appling label encoding on ER,PR AND HERS2 STATUS

# %%
list[f.columns]
# Out:
# list[Index(['Age', 'Gender', 'Protein1', 'Protein2', 'Protein3', 'Protein4',
#        'Tumour_Stage', 'Histology', 'ER status', 'PR status', 'HER2 status',
#        'Surgery_type', 'Date_of_Surgery', 'Date_of_Last_Visit',
#        'Patient_Status'],
#       dtype='object')]

# %%
from sklearn.preprocessing import LabelEncoder
g=LabelEncoder()
f['ER status']=g.fit_transform(f['ER status'])

# %%
f.head(15)
# Out:
#     Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0    42  FEMALE   0.95256   2.15000  0.007972 -0.048340             1
# 1    54  FEMALE   0.00000   1.38020 -0.498030 -0.507320             1
# 2    63  FEMALE  -0.52303   1.76400 -0.370190  0.010815             1
# 3    78  FEMALE  -0.87618   0.12943 -0.370380  0.132190             0
# 4    42  FEMALE   0.22611   1.74910 -0.543970 -0.390210             1
# 5    80  FEMALE   0.46647   2.57970 -1.253700  0.151540             2
# 6    66  FEMALE  -0.72486  -0.28289  0.959430  0.350900             1
# 7    36  FEMALE   0.46931   1.55260 -0.165240 -0.275990             2
# 8    58  FEMALE  -1.26850   0.10613  1.135200 -0.394920             1
# 9    62  FEMALE   0.64934   1.81680  0.279260  0.132280             1
# 10   51  FEMALE  -0.38466   0.80609 -1.627400 -0.512910             1
# 11   40  FEMALE  -0.56570   1.26680 -0.293460  0.193950             1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
M=LabelEncoder()
f[ 'PR status']=M.fit_transform(f[ 'PR status'])

# %%
from sklearn.preprocessing import LabelEncoder
k=LabelEncoder()
f[ 'HER2 status']=k.fit_transform(f[ 'HER2 status'])

# %%
sns.heatmap(f.corr(),annot=True,cmap='BuPu')
# Out:
# <AxesSubplot:>

# %% [raw]
# one sample t test

# %%
f['HER2 status']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 329    1
# 330    1
# 331    0
# 332    0
# 333    0
# Name: HER2 status, Length: 334, dtype: int32

# %%
n=f[(f["Age"]>50) & (f["HER2 status"]==1)]

# %%
n
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 10    51  FEMALE -0.384660   0.80609 -1.627400 -0.512910             1
# 58    63  FEMALE -0.037253   1.09070 -0.423810 -0.305360             0
# 67    83  FEMALE -2.144600  -0.17946 -0.200330 -1.488800             2
# 76    60  FEMALE  0.252870   2.29670  0.532440  0.046291             2
# 93    52  FEMALE  0.784180   2.29380 -0.438620 -0.047829             2
# 95    79  FEMALE -0.036229   0.79551 -0.013525  1.629900             1
# 123   61  FEMALE  0.383060   1.65460  0.573010  0.348220             2
# 148   56  FEMALE  1.035200   1.76460 -0.759210  0.975270             2
# 166   53  FEMALE -0.627800   0.26102 -0.204200 -1.305300             2
# 173   63  FEMALE -0.559570   0.48445  0.081055  0.609830             1
# 179   79  FEMALE  0.479400   2.05590 -0.531360 -0.188480             0
# 212   85  FEMALE  0.745200   1.75730 -1.006200 -0.061740             1
# ...

# %%
n["Age"].mean()
# Out:
# 65.76470588235294

# %% [raw]
# t sample test is that if a person is above 50 then the mean age for hers==1 is 65.7,is it same for rest of the populTION
#
# N0=avg monthly hours of an employee for hers==1 is 65.7,
# N1 is it true for rest of the population

# %%
m=f[f["HER2 status"]==1]

# %%
m.shape
# Out:
# (29, 15)

# %%
sample=m.sample(15,random_state=0)

# %%
from scipy.stats import ttest_1samp

# %%
mean_Age=65.7

# %%
statistics,pvalue=ttest_1samp(sample["Age"],65.7)
statistics,pvalue
# Out:
# (-2.8166077772655584, 0.013724130272658926)

# %%
n=len(m["Age"])
dof=n-1
dof
alpha=0.05

# %%
from scipy.stats import t
cv=t.ppf([alpha/2,1-alpha/2],dof)

# %%
cv
# Out:
# array([-2.04840714,  2.04840714])

# %% [raw]
# p value is less than 0.05 ,so reject the null hypothesis,the mean is not 65.7 for the entire population

# %%
f
# Out:
#      Age  Gender  Protein1  Protein2  Protein3  Protein4  Tumour_Stage  \
# 0     42  FEMALE  0.952560   2.15000  0.007972 -0.048340             1
# 1     54  FEMALE  0.000000   1.38020 -0.498030 -0.507320             1
# 2     63  FEMALE -0.523030   1.76400 -0.370190  0.010815             1
# 3     78  FEMALE -0.876180   0.12943 -0.370380  0.132190             0
# 4     42  FEMALE  0.226110   1.74910 -0.543970 -0.390210             1
# ..   ...     ...       ...       ...       ...       ...           ...
# 329   59  FEMALE  0.024598   1.40050  0.024751  0.280320             1
# 330   41  FEMALE  0.100120  -0.46547  0.472370 -0.523870             0
# 331   54  FEMALE  0.753820   1.64250 -0.332850  0.857860             1
# 332   74  FEMALE  0.972510   1.42680 -0.366570 -0.107820             1
# 333   66  FEMALE  0.286380   1.39980  0.318830  0.836050             1
#
#                           Histology  ER status  PR status  HER2 status  \
# ...

# %% [markdown]
# # z test

# %%
f["Surgery_type"].unique()
# Out:
# array(['Other', 'Lumpectomy', 'Modified Radical Mastectomy',
#        'Simple Mastectomy'], dtype=object)

# %%
n=((f["Surgery_type"]=='Lumpectomy')&(f['Patient_Status']=='Alive')).sum()

# %% [raw]
# n=(surgery type =Lumpectomy, Patient_Status=Alive)=57
#
# percentage wise=57/334  =0.17
#
# N0= n is 0.17-no.of patients alive after appling lumpectomy is same as is doing any other surgery
# N1= n is  0.17  for patients using all different kinds of surgery.

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
sample1=f.sample(100,random_state=0)

# %%
m=len(sample1['Surgery_type'])

# %%
p0=0.17

# %%
#count=total success possibility
count=(sample1['Surgery_type']=='Lumpectomy')&(f['Patient_Status']=='Alive')

# %%
count.sum()
# Out:
# 16

# %%
statistics_oneprop,pvalue_oneprop=proportions_ztest(count=16,nobs=100,value=p0,alternative="two-sided",prop_var=False)

# %%
pvalue_oneprop
# Out:
# 0.7850282054929875

# %% [markdown]
# p value is more that 0.05,
# so there is a strong evidence to believe N0
